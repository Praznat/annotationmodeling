# %%
# %load_ext autoreload
# %autoreload 2
import json
import random
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import experiments
import utils
import experiment_manager as mngr
from eval_functions import iou_score_multi
from agreement import InterAnnotatorAgreement
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bbexp = mngr.BBExperiment()
bbexp.setup(n_items=24, skip_gran=True)
# Out:
# 100%|██████████| 200/200 [00:09<00:00, 21.37it/s]

# %%
def inv_iou(x, y):
    return 1 - iou_score_multi(x, y)
iaa = InterAnnotatorAgreement.create_from_experiment(bbexp, distance_fn=inv_iou)
iaa.setup()

# %%
iaa.plot_matrix(show_grid=False)

# %%
iaa.plot_distance_distributions()

# %%
iaa.get_krippendorff_alpha()
# Out:
# 0.5052830081759159
