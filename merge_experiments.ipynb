# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import experiments
from experiment_manager import *

# %%
test_experiment("affect", AffectExperiment)
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 18.47it/s]
# 38 & 100 & 1000 & 26.32$\pm$31.92 & 10.0$\pm$0.0 & 60
# None
# Pickled model loaded
# Pickled model loaded
# dem 1.5132901668548584
# mas 4.765300989151001
#    index Dataset name Eval Fn name Dist Fn name  \
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
# 0      0       affect      default      default
#
#                        Agg method name Predicted  Eval score  \
# 0                          RANDOM USER      None    5.401702
# ...

# %%
test_experiment("pico", PICOExperiment)
# Out:
# ...
# 100%|██████████| 482/482 [00:15<00:00, 31.34it/s]
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 100%|██████████| 670/670 [00:21<00:00, 30.99it/s]
# 91 & 191 & 1165 & 12.8$\pm$36.86 & 6.1$\pm$2.4 & 87
# None
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# /Users/alexbraylan/Tools/annotationmodeling/merge_functions.py:25: RuntimeWarning: invalid value encountered in double_scalars
#   frac_non_empty = sum(non_empty_wgts) / sum(weights)
# /Users/alexbraylan/Tools/annotationmodeling/merge_functions.py:40: RuntimeWarning: invalid value encountered in true_divide
#   start = np.round(sum_start / sum_wgt).astype(int)
# /Users/alexbraylan/Tools/annotationmodeling/merge_functions.py:41: RuntimeWarning: invalid value encountered in true_divide
#   end = np.round(sum_end / sum_wgt).astype(int)
# ...

# %%
# test_experiment("NER", NERExperiment)

# %%
test_experiment("boundingbox", BBExperiment)
# Out:
# ...
#   0%|          | 2/544 [00:00<00:29, 18.32it/s]/Users/alexbraylan/Tools/annotationmodeling/mas/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/alexbraylan/Tools/annotationmodeling/mas/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...
#   0%|          | 2/877 [00:00<00:53, 16.49it/s]/Users/alexbraylan/Tools/annotationmodeling/mas/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/alexbraylan/Tools/annotationmodeling/mas/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...
# 100%|██████████| 1172/1172 [01:17<00:00, 15.19it/s]
# 196 & 200 & 1723 & 8.79$\pm$23.4 & 8.62$\pm$1.88 & 0
# None
# Pickled model loaded
# ...

# %%
test_experiment("keypoints", SimKeypointsExperiment)

# %%
test_experiment("ranking", SimRankingExperiment)

# %%
# from eval_functions import gleu2way
# def gleu_dist(x, y):
#     try:
#         return 1 - gleu2way(x["rat"], y["rat"])
#     except: # fails when NaN
# #         print(F"failed on {x}, {y}")
#         return 1
# test_experiment("rationales", RationalesExperiment, dist_fn_dict={"default":None, "gleu":gleu_dist})
