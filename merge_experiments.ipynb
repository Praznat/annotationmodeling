# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import experiments
from experiment_manager import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test_experiment("affect", AffectExperiment)
# Out:
#  32%|███▏      | 32/100 [00:01<00:03, 20.03it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-889e88f7113e> in <module>()
# ----> 1 test_experiment("affect", AffectExperiment)
#
# ~/Tools/annotationmodeling/experiment_manager.py in test_experiment(experiment_name, experiment_factory, eval_fn_dict, dist_fn_dict, debug)
#     296                 print("\n", eval_name, dist_name)
#     297             the_experiment = experiment_factory(eval_fn=eval_fn, dist_fn=dist_fn)
# --> 298             the_experiment.setup()
#     299             the_experiment.train(dem_iter=500, mas_iter=500)
#     300             if hasattr(the_experiment, "merge_fn"):
#
# ~/Tools/annotationmodeling/experiment_manager.py in setup(self)
#      73         full_df = full_df[["item", "uid", "annotation", "groundtruth"]]
#      74
# ...

# %%
test_experiment("pico", PICOExperiment)
# Out:
# ...
# 100%|██████████| 670/670 [00:15<00:00, 44.50it/s]
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
#    index Dataset name Eval Fn name Dist Fn name  \
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# 0      0         pico      default      default
# ...

# %%
test_experiment("NER", NERExperiment)
# Out:
# 100%|██████████| 199/199 [00:02<00:00, 68.30it/s]
# Pickled model loaded
# Pickled model loaded
#    index Dataset name Eval Fn name Dist Fn name  \
# 0      0          NER      default      default
# 0      0          NER      default      default
# 0      0          NER      default      default
# 0      0          NER      default      default
# 0      0          NER      default      default
# 0      0          NER      default      default
#
#                        Agg method name Predicted  Eval score Misc.
# 0                          RANDOM USER      None    0.632441  None
# 0                  BEST AVAILABLE USER      None    0.808146  None
# 0            SMALLEST AVERAGE DISTANCE      None    0.794829  None
# 0    DISTANCE EXPECTATION MAXIMIZATION      None    0.805182  None
# 0  MULTIDIMENSIONAL ANNOTATION SCALING      None    0.821136  None
# 0                               ORACLE      None    0.867816  None

# %%
test_experiment("boundingbox", BBExperiment)
# Out:
# ...
#   0%|          | 0/581 [00:00<?, ?it/s]/Users/alexbraylan/Tools/annotationmodeling/mas/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/alexbraylan/Tools/annotationmodeling/mas/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...
# 100%|██████████| 1077/1077 [00:07<00:00, 141.85it/s]
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
# Pickled model loaded
#    index Dataset name Eval Fn name Dist Fn name  \
# 0      0  boundingbox      default      default
# 0      0  boundingbox      default      default
# 0      0  boundingbox      default      default
# 0      0  boundingbox      default      default
# 0      0  boundingbox      default      default
# 0      0  boundingbox      default      default
# ...
